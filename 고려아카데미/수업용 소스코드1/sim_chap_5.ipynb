# %%
#sim_chap_5

from matplotlib import pyplot as plt , font_manager
import numpy as np
import math

# 한글 폰트 사용하기 위해 설정
# 윈도 10에 있는 기본 폰트 파일을 사용하도록 설정하기

import matplotlib.font_manager as fm
import matplotlib

font_location = "C:/Windows/Fonts/HYCYSM.TTF"
font = fm.FontProperties(fname = font_location).get_name()
matplotlib.rc('font', family=font_name)

# %%
import pandas as pd

df = pd.read_csv('C:\\python 3.5\\py_test\\야구선수성적.csv',
                 encoding='euc-kr')
df.head(10)

print(df)
# Out:
#    선수명  경기수   타수   득점   안타
# 0  홍길동  137  476   84  176
# 1  일지매  131  483   91  177
# 2  전우치  106  388   84  141
# 3  강감찬  125  498  103  173

# %%
# 문제 1 : 데이터 만들기
# data1 에 경기수 컬럼 할당
#data1 = ######## <- 여기에 입력창 만들어 주세요

#data2 에 득점 컬럼 할당
#data2 = ####### <- 여기에 입력창 만들어 주세요

#data3에 안타 컬럼 할당
#data3 = ####### <- 여기에 입력창 만들어 주세요

# 위 정답 코드
data1 = df['경기수']
data2 = df['득점']
data3 = df['안타']



name = df['선수명']

# %%
# 라인그래프 설정
plt.style.use('ggplot')
fig = plt.figure()
ax = fig.add_subplot(111)

# 문제 2 : 그래프 그리기
ax.plot( ### , ### , label ='경기수')  # <- 왼쪽의 ### 자리에 입력창
ax.plot( ### , ### , label='득점')     # <- 왼쪽의 ### 자리에 입력창
ax.plot( ### , ### , label='안타')     # <- 왼쪽의 ### 자리에 입력창 



# 위 정답 코드
ax.plot(name , data1 , label = '경기수')
ax.plot(name , data2 , label = '득점')
ax.plot(name , data3 , label = '안타')

#축 제목과 범례 그리기
ax.set_title('선수별 기록',fontproperties = font)
ax.set_ylabel('건수(단위:건)',fontproperties = font)
ax.set_xlabel('선수명',fontproperties = font)
ax.legend(loc=1)
plt.show()
